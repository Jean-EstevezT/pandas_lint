# %%
import pandas as pd

# %%
# PERF003: String Accessor
df['col'].apply(lambda x: x.upper())

# %%
# PERF004: Date Accessor
df['date'].apply(lambda x: x.year)

# %%
# STY001: Inplace
df.drop(columns=['a'], inplace=True)

# %%
# IO001: efficient format
df.to_csv('out.csv')
